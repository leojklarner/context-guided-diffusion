# %%
import pandas as pd
import json
import numpy as np
import os
import seaborn as sns
import matplotlib.pyplot as plt

from rdkit import Chem
from rdkit.Chem import QED, AllChem
from rdkit.Chem.Descriptors import ExactMolWt
from scipy.stats import pearsonr
from copy import deepcopy

import umap
import umap.plot

from tqdm import tqdm
tqdm.pandas()
# Out:
# /data/stat-cadd/bras5033/envs/GaUDI/lib/python3.8/site-packages/umap/distances.py:1063: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# /data/stat-cadd/bras5033/envs/GaUDI/lib/python3.8/site-packages/umap/distances.py:1071: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# ...

# %%
sims_bit = pd.Series(np.load("tanimoto_sims_cache.npy").max(1), copy=False)

# %%
sims_bit[sims_bit > sims_bit.median()].mean(), sims_bit[sims_bit > sims_bit.median()].std()
# Out:
# (0.4220937165383822, 0.05843929407628981)

# %%
sims_bit[sims_bit <= sims_bit.median()].mean(), sims_bit[sims_bit <= sims_bit.median()].std()
# Out:
# (0.3109338893132214, 0.034626870161481436)

# %% [markdown]
# # Get smaller context sets

# %%
"""context_data = pd.read_csv("zinc500k.csv")

context_set_50 = context_data.sample(frac=0.1, random_state=42)
context_set_5 = context_data.sample(frac=0.01, random_state=42)
context_set_05 = context_data.sample(frac=0.001, random_state=42)

display(len(context_set_50), len(context_set_5), len(context_set_05))

context_set_50.to_csv("zinc50k.csv", index=False)
context_set_5.to_csv("zinc5k.csv", index=False)
context_set_05.to_csv("zinc05k.csv", index=False)"""
# Out:
# 'context_data = pd.read_csv("zinc500k.csv")\n\ncontext_set_50 = context_data.sample(frac=0.1, random_state=42)\ncontext_set_5 = context_data.sample(frac=0.01, random_state=42)\ncontext_set_05 = context_data.sample(frac=0.001, random_state=42)\n\ndisplay(len(context_set_50), len(context_set_5), len(context_set_05))\n\ncontext_set_50.to_csv("zinc50k.csv", index=False)\ncontext_set_5.to_csv("zinc5k.csv", index=False)\ncontext_set_05.to_csv("zinc05k.csv", index=False)'

# %% [markdown]
# # Get differential context sets

# %%
# get context set fps
context_set_50 =  pd.read_csv("zinc500k.csv").sample(frac=0.2, random_state=42)
ecfps = context_set_50["smiles"].progress_apply(
    lambda m: np.array(AllChem.GetMorganFingerprintAsBitVect(Chem.MolFromSmiles(m), useChirality=True, radius=2, nBits=2048)))
fps = np.vstack(ecfps)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 100000/100000 [03:49<00:00, 435.27it/s]

# %%
training_data = pd.read_csv("zinc250k.csv").sample(frac=0.02, random_state=42)
ecfps_train = training_data["smiles"].progress_apply(
    lambda m: np.array(AllChem.GetMorganFingerprintAsBitVect(Chem.MolFromSmiles(m), useChirality=True, radius=2, nBits=2048)))
fps_train = np.vstack(ecfps_train)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4989/4989 [00:11<00:00, 434.69it/s]

# %%
sims_bit = fps @ fps_train.T
sims_bit = sims_bit / (fps.sum(-1, keepdims=True) + fps_train.sum(-1, keepdims=True).T - sims_bit)

# %%
np.save("tanimoto_sims_cache.npy", sims_bit)

# %%
clostest_sims = pd.Series(sims_bit.max(1))

# %%
similarity_filter = clostest_sims > clostest_sims.median()

# %%
context_set_50.reset_index(drop=True)[similarity_filter]["smiles"].to_csv("ZINC50k_most_similar.csv", index=False)
context_set_50.reset_index(drop=True)[~similarity_filter]["smiles"].to_csv("ZINC50k_least_similar.csv", index=False)

# %%
sims_bit_subset_int = fps[:100] @ fps_train[:100].T
sims_bit_subset_int = sims_bit_subset_int / (fps[:100].sum(-1, keepdims=True) + fps_train[:100].sum(-1, keepdims=True).T - sims_bit_subset_int)

# %%
sims_bit_subset_float = fps[:100].astype(float) @ fps_train[:100].astype(float).T
sims_bit_subset_float = sims_bit_subset_float / (fps[:100].astype(float).sum(-1, keepdims=True) + fps_train[:100].astype(float).sum(-1, keepdims=True).T - sims_bit_subset_float)

# %%
training_data = pd.read_csv("zinc250k.csv")#.sample(n=10_000, random_state=0)
context_data = pd.read_csv("zinc500k.csv")#.sample(n=10_000, random_state=0)


df = pd.concat([
    pd.DataFrame({"smiles": training_data["smiles"], "Dataset": "labeled dataset"}),
    pd.DataFrame({"smiles": context_data["smiles"], "Dataset": "unlabeled context points"}),
])

df = df.dropna()
df["Dataset"].value_counts()
# Out:
# unlabeled context points    500000
# labeled dataset             249455
# Name: Dataset, dtype: int64

# %%
# derive molecular properties and also add number of heavy atoms
df["mol"] = df["smiles"].progress_apply(AllChem.MolFromSmiles)

props = df.progress_apply(lambda x: QED.properties(x['mol'])._asdict(), axis=1, result_type='expand')
df = df.join(props)
mol_props = props.columns.to_list()
mol_props.remove('ALERTS')
df["num_atoms"] = df["mol"].apply(lambda x: x.GetNumHeavyAtoms())
mol_props.append("num_atoms")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 # derive molecular properties and also add number of heavy atoms
# ----> 2 df["mol"] = df["smiles"].progress_apply(AllChem.MolFromSmiles)
#       4 props = df.progress_apply(lambda x: QED.properties(x['mol'])._asdict(), axis=1, result_type='expand')
#       5 df = df.join(props)
#
# NameError: name 'df' is not defined

# %%
mol_prop_map={
    "MW": "molecular weight", "num_atoms": "number of atoms", 
    'HBA': "number of H-bond acceptors","ALOGP": "lipophilicity", 'HBD': "number of H-bond donors", 'ROTB': "number of rotable bonds", 
    'AROM': "number of aromatic rings", "PSA": "polarizable surface area",
}

for c in df.columns:
    if c in mol_prop_map and "number" in mol_prop_map[c]:
        df[c] = df[c].astype(int)

# %%
plot_df = pd.melt(
    frame=df,
    id_vars=["Dataset"],
    value_vars=mol_props,
    var_name='property'
)

fig, axs = plt.subplots(figsize=(12, 6), nrows=2, ncols=4)

for i, mol_prop in enumerate(mol_prop_map.keys()):
    
    is_discrete = "number" in mol_prop_map[mol_prop]
    
    g = sns.histplot(
        data=df, x=mol_prop, hue="Dataset", common_norm=True, common_bins=False,
        stat='probability', ax=axs[i//4, i%4],
        discrete=is_discrete, element="step",
        alpha=0.2, bins=100 if not is_discrete else "auto"
    )
    axs[i//4, i%4].set_xlabel(mol_prop_map[mol_prop])
    #axs[i//4, i%4].get_legend().remove()
    #if i == 2:
    #    axs[i//3, i%3].get_legend().remove()

    
handles = axs[0,0].get_legend().legend_handles
labels = [l.get_text() for l in list(axs[0,0].get_legend().get_texts())]
# Get the handles and labels from any one of the subplots
#handles, labels = axs[0, 0].get_legend_handles_labels()

for i in range(8):
    axs[i//4, i%4].get_legend().remove()

# Create a single legend for the figure
fig.legend(handles, labels, loc='upper center', bbox_to_anchor=(0.5, 1.1), fontsize="large",)

sns.despine()
plt.tight_layout()

fig.savefig("zinc_properties.pdf", bbox_inches="tight")

# %%
# Out:
# 'labeled dataset'

# %%
axs[0,0].get_legend().get_texts()
# Out:
# [Text(0, 0, 'labeled dataset'), Text(0, 0, 'unlabeled context points')]

# %%
ecfps = df["mol"].progress_apply(lambda m: np.array(AllChem.GetMorganFingerprintAsBitVect(m, useChirality=True, radius=2, nBits=2048)))
fps = np.vstack(ecfps)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1248365/1248365 [19:36<00:00, 1061.26it/s]

# %%
# drop features with zero variance
print("Dropping", (fps.var(0) == 0).sum(), "features with zero variance.")
fps = fps[:, fps.var(0) > 0]
# Out:
# Dropping 0 features with zero variance.

# %%
prod_bit = fps @ fps.T
summ_bit = fps.sum(-1, keepdims=True)
summ_bit = summ_bit + summ_bit.T
sims_bit = prod_bit / (summ_bit - prod_bit)

# %%
mapper = umap.UMAP(n_neighbors=10, min_dist=0.01, metric="precomputed").fit(1-sims_bit)
umap.plot.points(mapper, labels=df["Dataset"], alpha=0.4)
# Out:
# /data/stat-cadd/bras5033/envs/GaUDI/lib/python3.8/site-packages/umap/umap_.py:1780: UserWarning: using precomputed metric; inverse_transform will be unavailable
#   warn("using precomputed metric; inverse_transform will be unavailable")
# <Axes: >

# %%
data = pd.read_csv("zinc250k.csv")

for protein in ['parp1', 'fa7', '5ht1b', 'braf', 'jak2']:
    y = np.clip(data[protein], 0., 20.) / 20.0
    y *= data['qed']
    y *= data['sa']
    
    # get larger half as test set
    test_idx = y[y > y.median()].index.to_list()
    with open(os.path.join(f'valid_idx_zinc250k_{protein}.json'), "w") as f:
        json.dump(test_idx, f)

# %%
# genreate noise subset of data
data = pd.read_csv("zinc250k.csv")
fig, axs = plt.subplots(ncols=5, nrows=4, figsize=(20,10))
gen = np.random.default_rng()

for i, protein in enumerate(['parp1', 'fa7', '5ht1b', 'braf', 'jak2']):
    y = deepcopy(data[protein].values)

    sns.histplot(x=y, ax=axs[0, i], element="step", stat="density")
    axs[0, i].axvline(y.mean(), color="green")
    axs[0, i].set_xlim(-1, 20)
    
    y += gen.normal(0, 1, y.shape)
    sns.histplot(x=y, ax=axs[1, i], element="step", stat="density")
    axs[1, i].axvline(y.mean(), color="green")
    axs[1, i].set_xlim(-1, 20)
    print(protein, y.std(), pearsonr(data[protein], y))
    
    sns.scatterplot(x=data[protein], y=y, ax=axs[3,i])
    
    data[protein] = y
    
for i, protein in enumerate(['parp1', 'fa7', '5ht1b', 'braf', 'jak2']):
    y = deepcopy(data[protein].values)

    sns.histplot(x=data[protein], ax=axs[2, i], element="step", stat="density")
    axs[2, i].axvline(y.mean(), color="green")
    axs[2, i].set_xlim(-1, 20)

    data[protein] = y
    
data.to_csv("zinc250k_noisy.csv")
# Out:
# parp1 1.8384556996383032 PearsonRResult(statistic=0.8384757217160682, pvalue=0.0)
# fa7 1.5993430773172523 PearsonRResult(statistic=0.7796856958024929, pvalue=0.0)
# 5ht1b 1.9264979397019557 PearsonRResult(statistic=0.8551369643250298, pvalue=0.0)
# braf 1.7618666908925942 PearsonRResult(statistic=0.8233884647652809, pvalue=0.0)
# jak2 1.6695088276886019 PearsonRResult(statistic=0.8008261284123691, pvalue=0.0)

# %%
data = pd.read_csv("zinc250k.csv").reset_index()
data["train"] = data["index"].isin(test_idx)

fig, axs = plt.subplots(ncols=5, figsize=(20,5))

for i, protein in enumerate(['parp1', 'fa7', '5ht1b', 'braf', 'jak2']):
    y = np.clip(data[protein], 0., 20.) / 20.0
    y *= data['qed']
    y *= data['sa']
    data[protein+"_label"] = y
    data[protein+"_test"] = y > y.median()
    
    sns.histplot(x=y, hue=data["train"], ax=axs[i], element="step", common_bins=False, common_norm=False, stat="density")
    axs[i].axvline(y[data["train"]].median(), color="red")
    axs[i].axvline(y[data["train"]].mean(), color="green")
    
    print(protein, y[data["train"]].median(), y[data["train"]].mean(), y[~data["train"]].median(), y[~data["train"]].mean())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 data = pd.read_csv("zinc250k.csv").reset_index()
# ----> 2 data["train"] = data["index"].isin(test_idx)
#       4 fig, axs = plt.subplots(ncols=5, figsize=(20,5))
#       6 for i, protein in enumerate(['parp1', 'fa7', '5ht1b', 'braf', 'jak2']):
#
# NameError: name 'test_idx' is not defined

# %%
data = pd.read_csv("zinc250k.csv")

fig, axs = plt.subplots(ncols=5, figsize=(20,5))

for i, protein in enumerate(['parp1', 'fa7', '5ht1b', 'braf', 'jak2']):
    y = np.clip(data[protein], 0., 20.) / 20.0
    y *= data['qed']
    y *= data['sa']
    data[protein+"_label"] = y
    data[protein+"_test"] = y > y.median()
    
    sns.histplot(x=y, hue=y > y.median(), ax=axs[i], element="step", common_bins=False)
    axs[i].axvline(y[y <= y.median()].median(), color="red")
    axs[i].axvline(y[y <= y.median()].mean(), color="green")
    
    print(protein, y[y <= y.median()].median(), y[y <= y.median()].mean(), y[y > y.median()].median(), y[y > y.median()].mean())
# Out:
# parp1 0.1881828791494085 0.17654174660025615 0.2684830249206594 0.2738772052538418
# fa7 0.15506098944928126 0.14468109496747084 0.22066049071165564 0.22522174624204394
# 5ht1b 0.17550277048322804 0.16573916357536547 0.26331801855177195 0.2685993288415468
# braf 0.18704066150055093 0.1756329751330013 0.2685922531043433 0.27387502380678397
# jak2 0.1814446437611879 0.17022251419290688 0.25772857199065957 0.2626298009203661

# %%
data = pd.read_csv("zinc250k.csv")

for protein in ['parp1', 'fa7', '5ht1b', 'braf', 'jak2']:
    y = np.clip(data[protein], 0., 20.) / 20.0
    y *= data['qed']
    y *= data['sa']
    
    # get larger half as test set
    test_idx = y[y > y.median()].index.to_list()
    with open(os.path.join(f'valid_idx_zinc250k_{protein}.json'), "w") as f:
        json.dump(test_idx, f)

# %%
data[data["prop_parp1"] < data["prop_parp1"].median()].index

# %%
data = pd.read_csv("zinc250k.csv")

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plot_df = pd.melt(
    frame=data,
    id_vars=['mw_split'],
    value_vars=['qed', 'sa', 'parp1', 'fa7', '5ht1b', 'braf', 'jak2'],
    var_name='property'
)
g = sns.FacetGrid(data=plot_df, col='property', sharex=False, sharey=False, col_wrap=4)
g.map_dataframe(sns.histplot, x='value', common_norm=False, hue='mw_split', common_bins=True, element='step', stat='density')
g.add_legend()

# %%
with open(os.path.join(f'valid_idx_zinc250k.json')) as f:
    test_idx = json.load(f)

# %%
data.loc[test_idx]
